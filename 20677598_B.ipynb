# %% [markdown]
# Pokémon:HKUST Cup
#
# Variables:
# 1.pokemon(dictionary):Storing the information of pokemons e.g. Name:[type,type serial number,HP stat point,attack stat point, defence stat point,special attack stat point,special defence stat point,speed stat point,pokemon ASCII art]
#
# 2.type_counter_message(dictionary):Storing the counter message between pokemons e.g. type[damage coefficient towards Fire,damage coefficient towards Grass,damage coefficient towards Water,damage coefficient towards Ground,damage coefficient towards Ice,damage coefficient towards Electric]
#
# 3.from_number_to_pokemon(dictionary):Converting number from user to the pokemon they choose e.g.[number:pokemon name]
#
# 4.from_number_to_attack_type(dictionary):Converting the number from user to the action they want to take e.g.[number:syntax of the action]
#
# 5.round_count(int): Counting the round
#
# 6.player_win_count(int): Counting the number of rounds won by user
#
# 7.computer_win_count(int): Counting the number of rounds won by computer
#
# 8.player_pokemon(str): Storing the pokemon chosen by user
#
# 9.computer_pokemon(str): Storing the pokemon chosen randomly by computer
#
# 10.player_pokemon_level(int): Storing the pokemon level of user(randomly gernerated from range 1-30)
#
# 11.computer_pokemon_level(int): Storing the pokemon level of computer(randomly gernerated from range 1-30)
#
# 12.player_HP(int->float): Storing the HP of user's pokemon in current round(HP=HP stat point*50+3*level)
#
# 13.computer_HP(int->float): Storing the HP of computer's pokemon in current round(HP=HP stat point*50+3*level)
#
# 14.player_action(int): Storing the action made by the user
#
# 15.computer_action(int): Storing the random action made by computer
#
# 15.computer_damage(int->float): Storing computer's damage to user(randomly attck type's stat point*random number 50-60)
#
# 16.player_damage(int->float): Storing user's damage to computer(chosen attck type's stat point*random number 50-60)
#
# 17.player_defence_type(int): Soring the corresponding defend type's coefficient(corresponding defence type stat point)
#
# 18.computer_defence_type(int): Soring the corresponding defend type's coefficient(corresponding defence type stat point)
#
#
# Functions:
# 1.Initiate each round(while loop):
# Randomly initialize HP(randomly gernerate level*3+HP stat point*50)
# Randomly initialize damage(chosen attack type's stat point*random integer between 50 and 60)
#
# 2.Start the fight(if-elif-else,while loop):
# End the game when a life less or equal to zero,who is under 0 first will lose the round. If both are under 0, then it will be a tie game.
# Display the result of this round
#
# 3.End the fight(if-else)
# Go back to the front to star next round if round is not greater than 3.
# Compare the number of round of player and computer, who wins more will be the final winner. If both win the same, then it is a tie game.
# Display the final result.
#
# 4.Choosing pokemon:
# Let the user to choose the pokemon(totally 6) they like, ask user to input a number correponding to the pokemon and search the data base to convert the number to pokemon and store it in the variable.
#
# 5.Chooing the action(if):
# Let the user choose the action they want to take(attack,special attack,run)
#
# 6.Determine the counter relationship between pokemons(for loop, if):
# Search the corresponding type counter message in the data base and adjust the damage
#
# 7.Ajusting the damage with the correponding defence(if-else):
# Adjusting the damage to original damage*defence stat point/10
#
# 8.Deside whether will dodge the attck/special attack(if-else):
# Using randomly gernerate number(1-100) to compare with 10*speed stat point, if random number is smaller then pokemon will dodge the attack/special attack
#
#
# Appendix(Message of pokemon and Counter relationship):
#
# Pokemon data:
#   Name       Type      HP   Attack  Dfence  Special attack  Special defence  Speed
# Charmander   Fire      3       4       3         4               3             4
# Bulbasaur    Grass     3       3       3         4               4             3
# Squirtle     Water     3       3       4         3               4             3
# Diglett     Ground     2       4       2         3               3             6
# Vanillite    Ice       3       3       3         4               4             3
# Picachu     Electric   3       4       3         3               3             6
#
# Damage coefficient:
#  Type      Fire  Grass  Water  Ground Ice Electric
# Fire        1      2     0.5     1     2     1
# Grass      0.5     1      2      2    0.5    1
# Water       2     0.5     1      2     1    0.5
# Ground      2      1     0.5     2     1     2
# Ice        0.5     2     0.5     2     1     1
# Electric   1      0.5     2     0.5    1     1

# %%
import random
#pokemon data
pokemon={'Charmander':['Fire',0,3,4,3,4,3,4,'''              _.--""`-..
            ,'          `.
          ,'          __  `.
         /|          " __   \
        , |           / |.   .
        |,'          !_.'|   |
      ,'             '   |   |
     /              |`--'|   |
    |                `---'   |
     .   ,                   |                       ,".
      ._     '           _'  |                    , ' \ `
  `.. `.`-...___,...---""    |       __,.        ,`"   L,|
  |, `- .`._        _,-,.'   .  __.-'-. /        .   ,    \
-:..     `. `-..--_.,.<       `"      / `.        `-/ |   .
  `,         """"'     `.              ,'         |   |  ',,
    `.      '            '            /          '    |'. |/
      `.   |              \       _,-'           |       ''
        `._'               \   '"\                .      |
           |                '     \                `._  ,'
           |                 '     \                 .'|
           |                 .      \                | |
           |                 |       L              ,' |
           `                 |       |             /   '
            \                |       |           ,'   /
          ,' \               |  _.._ ,-..___,..-'    ,'
         /     .             .      `!             ,j'
        /       `.          /        .           .'/
       .          `.       /         |        _.'.'
        `.          7`'---'          |------"'_.'
       _,.`,_     _'                ,''-----"'
   _,-_    '       `.     .'      ,\
   -" /`.         _,'     | _  _  _.|
    ""--'---"""""'        `' '! |! /
                            `" " -' '''],'Bulbasaur':['Grass',1,3,3,3,4,4,3,'''                                           /
                        _,.------....___,.' ',.-.
                     ,-'          _,.--"        |
                   ,'         _.-'              .
                  /   ,     ,'                   `
                 .   /     /                     ``.
                 |  |     .                       \.\
       ____      |___._.  |       __               \ `.
     .'    `---""       ``"-.--"'`  \               .  \
    .  ,            __               `              |   .
    `,'         ,-"'  .               \             |    L
   ,'          '    _.'                -._          /    |
  ,`-.    ,".   `--'                      >.      ,'     |
 . .'\'   `-'       __    ,  ,-.         /  `.__.-      ,'
 ||:, .           ,'  ;  /  / \ `        `.    .      .'/
 j|:D  \          `--'  ' ,'_  . .         `.__, \   , /
/ L:_  |                 .  "' :_;                `.'.'
.    ""'                  """""'                    V
 `.                                 .    `.   _,..  `
   `,_   .    .                _,-'/    .. `,'   __  `
    ) \`._        ___....----"'  ,'   .'  \ |   '  \  .
   /   `. "`-.--"'         _,' ,'     `---' |    `./  |
  .   _  `""'--.._____..--"   ,             '         |
  | ." `. `-.                /-.           /          ,
  | `._.'    `,_            ;  /         ,'          .
 .'          /| `-.        . ,'         ,           ,
 '-.__ __ _,','    '`-..___;-...__   ,.'\ ____.___.'
 `"^--'..'   '-`-^-'"--    `-^-'`.''"""""`.,^.`.--' '''],'Squirtle':['Water',2,3,3,4,3,4,3,"""               _,........__
            ,-'            "`-.
          ,'                   `-.
        ,'                        \
      ,'                           .
      .'\               ,"".       `
     ._.'|             / |  `       \
     |   |            `-.'  ||       `.
     |   |            '-._,'||       | \
     .`.,'             `..,'.'       , |`-.
     l                       .'`.  _/  |   `.
     `-.._'-   ,          _ _'   -" \  .     `
`."'""'-.`-...,---------','         `. `....__.
.'        `"-..___      __,'\          \  \     \
\_ .          |   `"'"'    `.           . \     \
  `.          |              `.          |  .     L
    `.        |`--...________.'.        j   |     |
      `._    .'      |          `.     .|   ,     |
         `--,\       .            `7""' |  ,      |
            ` `      `            /     |  |      |    _,-'"''`-.
             \ `.     .          /      |  '      |  ,'          `.
              \  v.__  .        '       .   \    /| /              \
               \/    `""\""''"`.       \   \  /.''                |
                `        .        `._ ___,j.  `/ .-       ,---.     |
                ,`-.      \         ."     `.  |/        j     `    |
               /    `.     \       /         \ /         |     /    j
              |       `-.   7-.._ .          |"          '         /
              |          `./_    `|          |            .     _,'
              `.           / `----|          |-............`---'
                \          \      |          |
               ,'           )     `.         |
                7____,,..--'      /          |
                                  `---.__,--.'"""],'Diglett':['Ground',3,2,4,2,3,3,6,"""         _,.---'""'"--.._
                   ,"                `-.
                 ,'                     `.
                /     _       ,.          `.
               /     ||      |"|            \
              /      ||      | |             \
             /       .'      `_'              L
            j                                 |
            |        __,...._                 |
            |      ."        `.               |
            |      '           )              |
            |       `-...__,.-'               |
            |                                 |
            |                                 |
         ...|                                 |
      _,'   |                                 |
  _,-'  ___ |                                 |.-----_
-' ,.--`.  \|                                 |     . \
,-'     ,  |--,                               |  _,'   `- -----._
      ,' ,'    - ----.            _,..       _|.',               \
 ,-""' .-             \  ____   `'  _-'`  ,-'     `.              `-
 .--'"`   ,--:`.       --    ,"'. ,'  ,'`,_
        _'__,' |  _,..'_    ,:______,-     --.         _.
        -__..--' '      ` ..`L________,___ _,     _,.-'
                                              '" ' """],'Vanillite':['Ice',4,3,3,3,4,4,3,"""      (        (                                                            
                                                                  %           (                                                             
                                                               .             .                                                              
                                                              (              (                                                              
                                                             #                (                                                             
                                                             *                #*                                                            
                                                         &     ..           ...    /*                                                       
                                                     &         .,.......... /.         #                                                    
                                                   %               .......               #                                                  
                                                                                          &                                                 
                                                 #                                                                                          
                                                 &                                        .                                                 
                                                  &...                                ... .                                                 
                                                   %@ .....                   ..........&                                                   
                                               &      .. .......................   ../* &                                                   
                                            #          ..............   ......... ....    ..                                                
                                         /                     . ..................          .                                              
                                       #                       ....                           /                                             
                                                  #    &                                        ,                                           
                                    ,                    .              *      &                 (                                          
                                       * .         .***@               .  @(                                                                
                                   %      *   #    ****/                /***%    #                /                                         
                                   * %.    #  %   *****& &           & &****,    .     %   %      .                                         
                                   #  *,,.(        @**% /            @ &****@    %   %       %    .                                         
                                   .   &(       ,      ,                &*,&    %   (       .. ...(                                         
                                    /.             *                   .      *       #.....&....                                           
                                     / ...            &((((((@@@@@(*//@   (.            &.*.....                                            
                                       % .......        @(///////////#.           .............&                                            
                                         # ............. .            .. ... ................&                                              
                                            (............................................./                                                 
                                               &   ............. ....................  @                                                    
                                                    # %/        .................   .&                                                        
                                                   # ..........        ...........                                                          
                                              (     .    *.......................&,%.                                                       
                                             #              @ .... *&,,,,,%,,...       .                                                    
                                                  /%(/*/    &,,,,..../,,,,*             /                                                   
                                                       &    .,,........*,..  /                                                              
                                                       /     .......,..,,..                                                                 
                                                            %     ...%,,,,/ ,                                                               
                                                         &    (   , .......*                                                                
                                                              /#%##%(.   '"""],'Picachu':['Electric',5,3,4,3,3,3,6,"""quu..__
 $$$b  `---.__
  "$$b        `--.                          ___.---uuudP
   `$$b           `.__.------.__     __.---'      $$$$"              .
     "$b          -'            `-.-'            $$$"              .'|
       ".                                       d$"             _.'  |
         `.   /                              ..."             .'     |
           `./                           ..::-'            _.'       |
            /                         .:::-'            .-'         .'
           :                          ::''\          _.'            |
          .' .-.             .-.           `.      .'               |
          : /'$$|           .@"$\           `.   .'              _.-'
         .'|$u$$|          |$$,$$|           |  <            _.-'
         | `:$$:'          :$$$$$:           `.  `.       .-'
         :                  `"--'             |    `-.     \
        :##.       ==             .###.       `.      `.    `\
        |##:                      :###:        |        >     >
        |#'     `..'`..'          `###'        x:      /     /
         \                                   xXX|     /    ./
          \                                xXXX'|    /   ./
          /`-.                                  `.  /   /
         :    `-  ...........,                   | /  .'
         |         ``:::::::'       .            |<    `.
         |             ```          |           x| \ `.:``.
         |                         .'    /'   xXX|  `:`M`M':.
         |    |                    ;    /:' xXXX'|  -'MMMMM:'
         `.  .'                   :    /:'       |-'MMMM.-'
          |  |                   .'   /'        .'MMM.-'
          `'`'                   :  ,'          |MMM<
            |                     `'            |tbap\
             \                                  :MM.-'
              \                 |              .''
               \.               `.            /
                /     .:::::::.. :           /
               |     .:::::::::::`.         /
               |   .:::------------\       /
              /   .''               >::'  /
              `',:                 :    .'
                                   `:.:' """]}
#Counter relationship
type_counter_message={'Fire':[1,2,0.5,1,2,1],'Grass':[0.5,1,2,2,0.5,1],'Water':[2,0.5,1,2,1,0.5],'Ground':[2,0.5,1,1,1,2],'Ice':[0.5,2,0.5,2,1,1],'Electric':[1,0.5,2,0.5,1,1]}
#conver from number to pokemon
from_number_to_pokemon={1:'Charmander',2:'Bulbasaur',3:'Squirtle',4:'Diglett',5:'Vanillite',6:'Picachu'}
#convert from number to action
from_number_to_attack_type={1:3,2:5,3:0}
#initialize game
round_count=1
player_win_count=0
computer_win_count=0
print('Welcome to the world final of the HKUST Pokemon Master Competition!')
print('You are going to fight against Ash Ketchum and the winner will be the Champion!')
print('There are three rounds of the final competition.\nSimple rule: who wins more will be the winner!\nHere we go! (ง •̀_•́)ง\n')

#game start 
while True:
    print('This is the '+str(round_count)+' round\n'+'Currently you have won '+str(player_win_count)+' round, ')
    #choosing pokemon and generate HP
    player_pokemon=from_number_to_pokemon[int(input("""Please select a pokemon to fight: 
    1.Charmander(Fire) 2.Bulbasaur(Grass) 3.Squirtle(Water) 
    4.Diglett(Ground) 5.Vanillite(Ice) 6.Picachu(Electric) 
    (Enter number only)\n"""))]
    computer_pokemon=from_number_to_pokemon[random.randint(1,6)]
    player_pokemon_level=random.randint(1,30)
    computer_pokemon_level=random.randint(1,30)
    player_HP=pokemon[player_pokemon][2]*50+3*player_pokemon_level
    computer_HP=pokemon[computer_pokemon][2]*50+3*computer_pokemon_level
    
    print('You selected '+player_pokemon+' Type: '+pokemon[player_pokemon][0]+' Level: '+str(player_pokemon_level)+' HP: '+str(player_HP)+'\n'+pokemon[player_pokemon][8])
    print('Ash Ketchum selected '+computer_pokemon+' Type: '+pokemon[computer_pokemon][0]+' Level: '+str(computer_pokemon_level)+' HP: '+str(computer_HP)+'\n'+pokemon[computer_pokemon][8])
    
    #round start
    while True:
        #choosing action 
        player_action=from_number_to_attack_type[int(input('Please select the action you want to take 1.Attack 2.Special Attack 3.Run(Enter number only): ' ))]
        if player_action==0:
            computer_win_count+=1
            round_count+=1
            break
        computer_action=from_number_to_attack_type[random.randint(1,2)]
        player_damage=pokemon[player_pokemon][player_action]*random.randint(50,60)
        computer_damage=pokemon[computer_pokemon][computer_action]*random.randint(50,60)
        for i in type_counter_message.keys():
            if pokemon[player_pokemon][0]==i:
                player_damage*=type_counter_message[i][pokemon[computer_pokemon][1]]
            elif pokemon[computer_pokemon][0]==i:
                computer_damage*=type_counter_message[i][pokemon[player_pokemon][1]]
        if computer_action==1:
            player_defence_type=4
        else:
            player_defence_type=6
        if player_action==1:
            computer_defence_type=4
        else:
            computer_defence_type=6
        player_damage*=(pokemon[player_pokemon][player_defence_type]/10)
        computer_damage*=(pokemon[computer_pokemon][player_defence_type]/10)
        player_damage=round(player_damage,1)
        computer_damage=round(computer_damage,1)
        
        #determine whether pokemon will dodge
        if pokemon[player_pokemon][7]*10>=random.randint(1,100):
            computer_damage=0
            print('Your '+player_pokemon+' dodged the attack from '+"Ash Ketchum's "+computer_pokemon+'!')
        else:
            player_HP=round(player_HP-float(computer_damage),1)
            print("Ash Ketchum's "+computer_pokemon+' caused '+str(computer_damage)+' to '+'your '+player_pokemon+'!')
            
        if pokemon[computer_pokemon][7]*10>=random.randint(1,100):
            player_damage=0
            print("Ash Ketchum's "+computer_pokemon+' dodged the attack from '+'your '+player_pokemon+'!')
        else:
            computer_HP=round(computer_HP-float(player_damage),1)
            print('Your '+player_pokemon+' caused '+str(player_damage)+' to '+"Ash Ketchum's "+computer_pokemon+'!')
        
        #End the round
        if player_HP>0 and computer_HP<=0:
            player_win_count+=1
            round_count+=1
            print('You win this round! (＾▽＾)\n')
            break
        elif computer_HP>0 and player_HP<=0:
            computer_win_count+=1
            round_count+=1
            print('Ash Ketchum wins this round! .·´¯`(>▂<)´¯`·. \n')
            break
        elif computer_HP<0 and player_HP<0:
            round_count+=1
            print('Is a tie game! You and Ash Ketchum are equal in strengh!\n')
            break
        print('Your '+player_pokemon+' has HP: '+str(player_HP)+' left!\n'+"Ash Ketchum's "+computer_pokemon+' has HP: '+str(computer_HP)+' left!\n')
    
    #End the game
    if round_count==3:
        if computer_win_count>player_win_count:
            print('Ash Ketchum wins!\nAsh Ketchum is the Pokemon Master in HKUST!')
        elif player_win_count>computer_win_count:
            print('You win!\nYou are the Pokemon Master in HKUST! /◕ヮ◕)/')s
        else:
            print('This is a tie game, you and Ash Ketchum are both the Pokemon Master in HKUST! n_n')
        break
